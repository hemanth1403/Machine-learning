# %%
a,b = 1,2
print(a+b, b-a,a*b, a/b, a%b, a//b)
# Out:
# 3 1 2 0.5 1 0

# %%
s1 = "hello"
s2 = "World"
print(s1+s2)
print(s1*5)
# Out:
# helloWorld
# hellohellohellohellohello

# %%
s1[:3]
# Out:
# 'hel'

# %%
ls = [1, 2, 3, 4]
print(ls)
ls.append(5)
print(ls)
del ls[0]
print(ls)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 5]
# [2, 3, 4, 5]

# %%
t = (1, 2,3)
(a, b, c) = t

# %%
d={1:"a", 2:"b", 3:"c"}
print(d.keys())
print(d.values())
print(d.items())
d[5] = "abc"
d
# Out:
# dict_keys([1, 2, 3])
# dict_values(['a', 'b', 'c'])
# dict_items([(1, 'a'), (2, 'b'), (3, 'c')])
# {1: 'a', 2: 'b', 3: 'c', 5: 'abc'}

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/ML Lab/Week_5/Salary_Data.csv")

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
y = data.iloc[:,-1]
x = data.iloc[:,:-1]

# %%
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
y.isnull().sum()
# Out:
# 0

# %%
x.isnull().sum()
# Out:
# YearsExperience    0
# dtype: int64

# %%
for i in range(len(x.iloc[1,:])):
  x.iloc[:,i] = x.iloc[:,i].fillna(x.iloc[:,i].mean())
# Out:
# <ipython-input-55-1c6f1ce25b59>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.iloc[:,i] = x.iloc[:,i].fillna(x.iloc[:,i].mean())

# %%
x.isnull().sum()
# Out:
# YearsExperience    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state =1)

# %%
import matplotlib.pyplot as mtp
mtp.scatter(x_train, y_train, color="green")   
mtp.show()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= lr.predict(x_test)  
x_pred= lr.predict(x_train)

# %%
x_pred
# Out:
# array([114272.87300929,  44275.78747434, 106806.51721889,  99340.1614285 ,
#        102140.0448499 ,  46142.37642194,  39609.31510534, 109606.40064029,
#         53608.73221233,  80674.27195251,  63874.97142412,  55475.32115993,
#        115206.16748308,  37742.72615775,  73207.91616212,  35876.13721015,
#         71341.32721452, 123605.81774728, 121739.22879968,  60141.79352893,
#         55475.32115993,  62941.67695033,  62941.67695033,  52675.43773853])

# %%
mtp.scatter(x_test, y_test, color="blue")   
mtp.plot(x_train, x_pred, color="red")     
mtp.show()
